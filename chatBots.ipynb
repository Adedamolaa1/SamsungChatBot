# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting tqdm
#   Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Collecting click
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Requirement already satisfied: joblib in c:\users\hp\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.3.2)
# Collecting regex>=2021.8.3
#   Using cached regex-2023.12.25-cp310-cp310-win_amd64.whl (269 kB)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python310\site-packages (from click->nltk) (0.4.6)
# Installing collected packages: tqdm, regex, click, nltk
# Successfully installed click-8.1.7 nltk-3.8.1 regex-2023.12.25 tqdm-4.66.2
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'C:\Users\HP\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import nltk
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# import spacy
lemmatizer = nltk.stem.WordNetLemmatizer()

# Download required NLTK data
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Error with downloaded zip file
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# True

# %%
import nltk
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# import spacy
lemmatizer = nltk.stem.WordNetLemmatizer()

# Download required NLTK data
#nltk.download('stopwords')
#nltk.download('punkt')
#nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# True

# %%
import pandas as pd 

data = pd.read_csv('Samsung Dialog.txt', sep = ':', header = None)
# Out:
#               0                                                  1
# 0      Customer   Hi, I'm looking to buy a new phone, and I'm i...
# 1   Sales Agent   Great, we have a wide range of Samsung phones...
# 2      Customer   Well, I want a phone with a good camera, long...
# 3   Sales Agent   Absolutely. We have a lot of great options th...
# 4      Customer              No, I haven't. Tell me more about it.
# 5   Sales Agent   The Galaxy S21 Ultra has a 108-megapixel came...
# 6      Customer          That sounds great. How much does it cost?
# 7   Sales Agent   The Galaxy S21 Ultra starts at $1,199, but we...
# 8      Customer   Okay, I'm interested. But I have a few more q...
# 9   Sales Agent   The Galaxy S21 Ultra comes with a standard on...
# 10     Customer   That's good to know. And what about the opera...
# 11  Sales Agent   Yes, the Galaxy S21 Ultra runs on Android 11,...
# 12     Customer   Okay, that's good. But I'm also interested in...
# 13  Sales Agent   Absolutely. The Galaxy A52 is a great mid-ran...
# 14     Customer   That sounds like a good option for me. How mu...
# 15  Sales Agent   The Galaxy A52 starts at $399, but again, we ...
# 16     Customer   Okay, I'll think about it. But can you also t...
# 17  Sales Agent   Of course. The Galaxy Z Fold2 is a really uni...
# 18     Customer   That sounds really cool, but it also sounds e...
# 19  Sales Agent   The Galaxy Z Fold2 starts at $1,999, but agai...
# 20     Customer   Hmm, I'm not sure. That's a lot of money for ...
# 21  Sales Agent   I understand. The Galaxy Z Fold2 is definitel...
# 22     Customer   Okay, can you tell me more about the Galaxy A72?
# 23  Sales Agent   Sure, the Galaxy A72 is another great mid-ran...
# 24     Customer   That sounds like a great option for me. How m...
# 25  Sales Agent   The Galaxy A72 starts at $449, but as I menti...
# 26     Customer   Okay, I'll definitely consider it. But before...
# 27  Sales Agent   Of course. We have a few different financing ...
# 28     Customer   That's good to know. And what if I have issue...
# 29  Sales Agent   Yes, we offer a lot of support options for ou...
# 30     Customer   Okay, that sounds great. I think I'm interest...
# 31  Sales Agent   Great, I'm glad to hear that. To buy the phon...
# 32     Customer   Okay, that sounds simple enough. Thanks for a...
# 33  Sales Agent   You're welcome. If you have any other questio...

# %%
sales = data.loc[(data[0] == 'Sales Agent' )]
cust = data.loc[(data[0] == 'Customer')]
sales.head()
#cust.head()
# Out:
#              0                                                  1
# 1  Sales Agent   Great, we have a wide range of Samsung phones...
# 3  Sales Agent   Absolutely. We have a lot of great options th...
# 5  Sales Agent   The Galaxy S21 Ultra has a 108-megapixel came...
# 7  Sales Agent   The Galaxy S21 Ultra starts at $1,199, but we...
# 9  Sales Agent   The Galaxy S21 Ultra comes with a standard on...

# %%
df = pd.DataFrame()
df['Questions'] = sales[1].reset_index(drop = True)
df['Answers'] =  cust[1].reset_index(drop = True)

df
# Out:
#                                             Questions  \
# 0    Great, we have a wide range of Samsung phones...
# 1    Absolutely. We have a lot of great options th...
# 2    The Galaxy S21 Ultra has a 108-megapixel came...
# 3    The Galaxy S21 Ultra starts at $1,199, but we...
# 4    The Galaxy S21 Ultra comes with a standard on...
# 5    Yes, the Galaxy S21 Ultra runs on Android 11,...
# 6    Absolutely. The Galaxy A52 is a great mid-ran...
# 7    The Galaxy A52 starts at $399, but again, we ...
# 8    Of course. The Galaxy Z Fold2 is a really uni...
# 9    The Galaxy Z Fold2 starts at $1,999, but agai...
# 10   I understand. The Galaxy Z Fold2 is definitel...
# 11   Sure, the Galaxy A72 is another great mid-ran...
# 12   The Galaxy A72 starts at $449, but as I menti...
# 13   Of course. We have a few different financing ...
# 14   Yes, we offer a lot of support options for ou...
# 15   Great, I'm glad to hear that. To buy the phon...
# 16   You're welcome. If you have any other questio...
#
#                                               Answers
# 0    Hi, I'm looking to buy a new phone, and I'm i...
# 1    Well, I want a phone with a good camera, long...
# 2               No, I haven't. Tell me more about it.
# 3           That sounds great. How much does it cost?
# 4    Okay, I'm interested. But I have a few more q...
# 5    That's good to know. And what about the opera...
# 6    Okay, that's good. But I'm also interested in...
# 7    That sounds like a good option for me. How mu...
# 8    Okay, I'll think about it. But can you also t...
# 9    That sounds really cool, but it also sounds e...
# 10   Hmm, I'm not sure. That's a lot of money for ...
# 11   Okay, can you tell me more about the Galaxy A72?
# 12   That sounds like a great option for me. How m...
# 13   Okay, I'll definitely consider it. But before...
# 14   That's good to know. And what if I have issue...
# 15   Okay, that sounds great. I think I'm interest...
# 16   Okay, that sounds simple enough. Thanks for a...

# %%
import nltk
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# import spacy
lemmatizer = nltk.stem.WordNetLemmatizer()

# %%
sent = 'I bought some phones two years back when it rained last years eve'
tokenized = nltk.word_tokenize(sent)

# %%
[lemmatizer.lemmatize(word.lower()) for word in tokenized]
# Out:
# ['i',
#  'bought',
#  'some',
#  'phone',
#  'two',
#  'year',
#  'back',
#  'when',
#  'it',
#  'rained',
#  'last',
#  'year',
#  'eve']

# %%
# Define a function for text preprocessing (including lemmatization)
def preprocess_text(text):
    # Identifies all sentences in the data
    sentences = nltk.sent_tokenize(text)

    # Tokenize and lemmatize each word in each sentence
    preprocessed_sentences = []
    for sentence in sentences:
        tokens = [lemmatizer.lemmatize(word.lower()) for word in nltk.word_tokenize(sentence) if word.isalnum()]
        # Turns to basic root - each word in the tokenized word found in the tokenized sentence - if they are all alphanumeric
        # The code above does the following:
        # Identifies every word in the sentence
        # Turns it to a lower case
        # Lemmatizes it if the word is alphanumeric

        preprocessed_sentence = ' '.join(tokens)
        preprocessed_sentences.append(preprocessed_sentence)

    return ' '.join(preprocessed_sentences)


df['tokenized Questions'] = df['Questions'].apply(preprocess_text)
df.head()
# Out:
#                                            Questions  \
# 0   Great, we have a wide range of Samsung phones...
# 1   Absolutely. We have a lot of great options th...
# 2   The Galaxy S21 Ultra has a 108-megapixel came...
# 3   The Galaxy S21 Ultra starts at $1,199, but we...
# 4   The Galaxy S21 Ultra comes with a standard on...
#
#                                              Answers  \
# 0   Hi, I'm looking to buy a new phone, and I'm i...
# 1   Well, I want a phone with a good camera, long...
# 2              No, I haven't. Tell me more about it.
# 3          That sounds great. How much does it cost?
# 4   Okay, I'm interested. But I have a few more q...
#
#                                  tokenized Questions
# 0  great we have a wide range of samsung phone to...
# 1  absolutely we have a lot of great option that ...
# 2  the galaxy s21 ultra ha a camera which take in...
# 3  the galaxy s21 ultra start at but we have some...
# 4  the galaxy s21 ultra come with a standard manu...

# %%
corpus = df['tokenized Questions'].to_list()
corpus
# Out:
# ['great we have a wide range of samsung phone to choose from what feature are you looking for in a phone',
#  'absolutely we have a lot of great option that meet those criterion have you considered the samsung galaxy s21 ultra',
#  'the galaxy s21 ultra ha a camera which take incredibly photo and video it also ha a battery which give you up to 11 hour of video playback time and up to 22 hour of talk time and with up to 512gb of storage you have plenty of space for all your photo video and apps',
#  'the galaxy s21 ultra start at but we have some great financing option that make it affordable for everyone',
#  'the galaxy s21 ultra come with a standard manufacturer warranty which cover defect in material and workmanship we also offer an extended warranty which can cover accidental damage theft and loss',
#  'yes the galaxy s21 ultra run on android 11 which is the latest version of the android operating system',
#  'absolutely the galaxy a52 is a great phone that ha a lot of the same feature a the galaxy s21 ultra but at a more affordable price point it ha a camera a battery and up to 256gb of storage it also run on the latest version of android and ha a really nice large display',
#  'the galaxy a52 start at 399 but again we have some great financing option that can make it more affordable',
#  'of course the galaxy z fold2 is a really unique phone that ha a foldable screen it a little more expensive than some of our other phone but it ha some really amazing feature for example it ha a foldable display which give you more screen real estate for multitasking and watching video it also ha a camera a battery and up to 512gb of storage',
#  'the galaxy z fold2 start at but again we have financing option that can make it more affordable',
#  'i understand the galaxy z fold2 is definitely a luxury phone and it not for everyone but if you looking for something more affordable we have a lot of other great samsung phone that might be a better fit for your budget',
#  'sure the galaxy a72 is another great phone that ha a lot of the same feature a the a52 but with a bigger display bigger battery and more camera it ha a super amoled display a battery and four camera including a main camera a camera an telephoto camera and a macro camera it also ha up to 256gb of storage and run on android 11',
#  'the galaxy a72 start at 449 but a i mentioned earlier we have financing option that can make it more affordable for you',
#  'of course we have a few different financing option available including a payment plan that let you pay for the phone over the course of 24 or 36 month with 0 interest we also have a program that can help reduce the cost of your new phone if you have an old phone that you no longer need',
#  'yes we offer a lot of support option for our samsung phone we have a dedicated customer support team that can help you with any issue you might have and we also have a lot of online resource and tutorial that can help you troubleshoot any problem on your own',
#  'great i glad to hear that to buy the phone you can either visit one of our store in person or order it online through our website if you choose to order it online you can customize your phone and choose your financing option during the checkout process',
#  'you welcome if you have any other question or concern do hesitate to reach out to u we always here to help']

# %%
# Vectorize corpus
tfidf_vectorizer = TfidfVectorizer()

vectorised_corpus = tfidf_vectorizer.fit_transform(corpus)
# TDIDF is a numerical statistic used to evaluate how important a word is to a document in a collection or corpus.
# The TfidfVectorizer calculates the Tfidf values for each word in the corpus and uses them to create a matrix where each row represents a document and each column represents a word.
# The cell values in the matrix correspond to the importance of each word in each document.
print(vectorised_corpus)
# Out:
#   (0, 84)	0.23660438686441437
#   (0, 69)	0.15998149699499475
#   (0, 96)	0.2637867896335805
#   (0, 199)	0.14102059469916212
#   (0, 25)	0.3020982345682903
#   (0, 63)	0.21552007724626251
#   (0, 193)	0.3020982345682903
#   (0, 71)	0.3020982345682903
#   (0, 38)	0.2637867896335805
#   (0, 178)	0.17111053916053845
#   (0, 134)	0.3199629939899895
#   (0, 154)	0.21552007724626251
#   (0, 116)	0.13279909422582864
#   (0, 145)	0.3020982345682903
#   (0, 195)	0.3020982345682903
#   (0, 77)	0.13279909422582864
#   (0, 190)	0.13279909422582864
#   (0, 75)	0.15998149699499475
#   (1, 181)	0.2043115607567
#   (1, 152)	0.2043115607567
#   (1, 72)	0.13926688912933677
#   (1, 173)	0.12423076983703787
#   (1, 41)	0.3359438625659739
#   (1, 45)	0.3359438625659739
#   (1, 175)	0.3359438625659739
#   :	:
#   (15, 84)	0.12343360671386412
#   (15, 199)	0.22070614398151203
#   (15, 38)	0.2752286657018131
#   (15, 178)	0.2677988089135773
#   (15, 134)	0.16692076967187802
#   (15, 116)	0.06927965869889657
#   (15, 75)	0.08346038483593901
#   (16, 80)	0.24801547268068733
#   (16, 16)	0.24801547268068733
#   (16, 128)	0.24801547268068733
#   (16, 146)	0.24801547268068733
#   (16, 81)	0.24801547268068733
#   (16, 54)	0.24801547268068733
#   (16, 40)	0.24801547268068733
#   (16, 144)	0.24801547268068733
#   (16, 192)	0.24801547268068733
#   (16, 23)	0.2165626866750337
#   (16, 79)	0.19424657985956148
#   (16, 124)	0.19424657985956148
#   (16, 83)	0.17693686262945363
#   (16, 126)	0.19424657985956148
#   (16, 199)	0.23154911515458088
#   (16, 178)	0.4214330611153068
#   (16, 77)	0.10902490103278203
#   (16, 190)	0.10902490103278203

# %%
def get_response(user_input):
    user_input_processed = preprocess_text(user_input) # ....................... Preprocess the user's input using the preprocess_text function

    user_input_vector = tfidf_vectorizer.transform([user_input_processed])# .... Vectorize the preprocessed user input using the TF-IDF vectorizer

    similarity_scores = cosine_similarity(user_input_vector, vectorised_corpus) # .. Calculate the score of similarity between the user input vector and the corpus (df) vector

    most_similar_index = similarity_scores.argmax() # ..... Find the index of the most similar question in the corpus (df) based on cosine similarity

    return df['Answers'].iloc[most_similar_index] # ... Retrieve the corresponding answer from the df DataFrame and return it as the chatbot's response
